# %% [markdown]
# ## Tunning the HyperParameters

# %%
from dask.distributed import Client, progress
client = Client(processes=False, threads_per_worker=4,
                n_workers=3, memory_limit='2GB')
client
# Out:
# <Client: 'inproc://172.28.0.2/62/1' processes=3 threads=12, memory=5.59 GiB>

# %%
from sklearn.svm import SVC
from sklearn.datasets import make_classification
from sklearn.model_selection import GridSearchCV

# %%
X, y = make_classification(n_samples=500,
                           random_state=0,
                           n_classes=3,
                           n_features=5,
                           n_informative=3,
                           n_redundant=2)
print(len(X[0]))
X[:2]
# Out:
# 5
# array([[ 1.35660265,  0.01737486, -0.39541825,  1.73600924,  0.69678037],
#        [-3.13368837, -3.58305728, -0.05784148,  0.47604655,  3.79569034]])

# %%
y[:2]
# Out:
# array([2, 1])

# %%
param_grid = {
    "C": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1],
    "kernel": ['rbf', 'poly', 'sigmoid'],
    "degree": [1, 2, 3, 4],
    "coef0": [1, 0.5, 0.3, 0.2 , 0.1],
    "gamma": ["auto", "scale"]
             }

# %%
clf = SVC(random_state=0, probability=True)

grid_search = GridSearchCV(clf,
                           param_grid=param_grid,
                           cv=3,
                           n_jobs=-1)

# %%
# %time grid_search.fit(X, y)
# Out:
# CPU times: user 10.8 s, sys: 960 ms, total: 11.8 s
# Wall time: 1min 19s
# GridSearchCV(cv=3, estimator=SVC(probability=True, random_state=0), n_jobs=-1,
#              param_grid={'C': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1],
#                          'coef0': [1, 0.5, 0.3, 0.2, 0.1],
#                          'degree': [1, 2, 3, 4], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid']})

# %%
import joblib

with joblib.parallel_backend('dask'):
    # %time _ = grid_search.fit(X, y)
# Out:
# CPU times: user 2min 32s, sys: 1.94 s, total: 2min 34s
# Wall time: 1min 20s

# %%
grid_search.predict(X)[:10]
# Out:
# array([2, 1, 2, 2, 1, 1, 2, 2, 0, 0])
