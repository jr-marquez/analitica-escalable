# %% [markdown]
# ## Regresiones con Dask ML

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster(processes=False, threads_per_worker=2, n_workers=3, memory_limit='2GB')
client = Client(cluster)
client
# Out:
# <Client: 'inproc://172.28.0.2/62/1' processes=3 threads=6, memory=5.59 GiB>

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression, Ridge

# %%
X, y = make_regression(n_samples=10000,
                       random_state=0,
                       n_features=10,
                       n_informative=6,
                      )
print(len(X[0]))
print(X)
# Out:
# 10
# [[ 0.74169828  1.25281176 -1.48850234 ... -0.29579711  0.65737716
#   -1.22572628]
#  [ 0.37140196  0.53166     0.45731118 ... -1.35014203  1.25723974
#    0.72830822]
#  [-1.0523336  -0.00522034  1.42785775 ...  1.07690868  0.53663147
#   -0.08779423]
#  ...
#  [-0.73962151 -0.958065   -0.10813259 ...  1.33390194  1.6249477
#    0.03537399]
#  [ 1.23021396 -2.07586322  0.81945104 ...  0.68948531  0.76437234
#   -2.73700434]
#  [-2.05906327  1.4013536  -0.98253952 ...  0.49919214 -0.04712177
#    0.38685995]]

# %%
clf = LinearRegression()

# %%
clf.fit(X, y)
# Out:
# LinearRegression()

# %%
clf2 = Ridge()
clf2.fit(X, y)
# Out:
# Ridge()

# %%
import joblib

with joblib.parallel_backend('dask'):
    clf.fit(X, y)

# %%
clf.predict(X)[:5]
# Out:
# array([  83.22334532,  -10.04653643,   -1.80084027,   96.06880674,
#        -210.42930151])
