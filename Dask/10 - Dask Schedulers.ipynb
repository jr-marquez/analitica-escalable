# %%
# !pip install "dask[complete]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from dask import delayed, compute
import dask

# %%
x = list(range(2, 20000, 2))
y = list(range(3, 30000, 3))
z = list(range(5, 50000, 5))

final_result = []

# %%
def do_something_1(x, y):
    return x + y + 2*x*y

def do_something_2(a, b):
    return a**3 - b**3

def do_something_3(p, q):
    return p*p + q*q

# %%
final_result = []
for i in range(0, len(x)):
    # Wrap the function calls inside delayed
    res_1 = delayed(do_something_1)(x[i], y[i])
    res_2 = delayed(do_something_2)(y[i], z[i])
    res_3 = delayed(do_something_3)(res_1, res_2)
    final_result.append(res_3)

final_sum = delayed(sum)(final_result)

# %% [markdown]
# ### Los multiprocesos crean una instancia por proceso, demora más porque no tienen memoria alocada como los multithread (mismo procesador)

# %%
with dask.config.set(scheduler='processes'):
    # %time _ = final_sum.compute()
# Out:
# CPU times: user 18 s, sys: 1.8 s, total: 19.8 s
# Wall time: 21.7 s

# %%
with dask.config.set(scheduler='sync'):
    # %time _ = final_sum.compute()
# Out:
# CPU times: user 1.55 s, sys: 19.8 ms, total: 1.57 s
# Wall time: 1.59 s

# %%
with dask.config.set(scheduler='threading'):
    # %time _ = final_sum.compute()
# Out:
# CPU times: user 3.01 s, sys: 693 ms, total: 3.7 s
# Wall time: 3.48 s

# %%
#dask.config.set(scheduler='threading'):

# %%
x = [2, 4, 6, 8]
y = [3, 6, 9, 12]
z = [5, 10, 15, 20]

final_result = []

# %%
import time

def do_something_1(x, y):
    time.sleep(4)
    return x + y + 2*x*y

def do_something_2(a, b):
    time.sleep(4)
    return a**3 - b**3

def do_something_3(p, q):
    time.sleep(4)
    return p*p + q*q

# %%
final_result = []
for i in range(0, len(x)):
    # Wrap the function calls inside delayed
    res_1 = delayed(do_something_1)(x[i], y[i])
    res_2 = delayed(do_something_2)(y[i], z[i])
    res_3 = delayed(do_something_3)(res_1, res_2)
    final_result.append(res_3)

final_sum = delayed(sum)(final_result)

# %%
with dask.config.set(scheduler='processes'):
    # %time _ = final_sum.compute()
# Out:
# CPU times: user 189 ms, sys: 82.5 ms, total: 271 ms
# Wall time: 28.1 s

# %%
with dask.config.set(scheduler='sync'):
    # %time _ = final_sum.compute()
# Out:
# CPU times: user 241 ms, sys: 33.8 ms, total: 275 ms
# Wall time: 48 s

# %%
with dask.config.set(scheduler='threading'):
    # %time _ = final_sum.compute()
# Out:
# CPU times: user 139 ms, sys: 21.2 ms, total: 161 ms
# Wall time: 28 s
