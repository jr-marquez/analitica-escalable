# %% [markdown]
# ## Pasos Previos

# %%
# !pip install "dask[complete]"

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster(processes=False, threads_per_worker=2, n_workers=3, memory_limit='2GB')
client = Client(cluster)
client
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/node.py:155: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45791 instead
#   http_address["port"], self.http_server.port
# <Client: 'inproc://172.28.0.2/61/53' processes=3 threads=6, memory=6.00 GB>

# %%
cluster.scheduler_info
# Out:
# {'address': 'inproc://172.28.0.2/61/53',
#  'id': 'Scheduler-c0a4fadb-9fd0-4c57-869f-ca92ecc0f0f2',
#  'services': {'dashboard': 45791},
#  'type': 'Scheduler',
#  'workers': {'inproc://172.28.0.2/61/55': {'host': '172.28.0.2',
#    'id': 0,
#    'local_directory': '/content/dask-worker-space/worker-5_jmk42f',
#    'memory_limit': 2000000000,
#    'name': 0,
#    'nanny': None,
#    'nthreads': 2,
#    'resources': {},
#    'services': {'dashboard': 38313},
#    'type': 'Worker'},
#   'inproc://172.28.0.2/61/56': {'host': '172.28.0.2',
#    'id': 1,
#    'local_directory': '/content/dask-worker-space/worker-7dmggsx0',
#    'memory_limit': 2000000000,
#    'name': 1,
#    'nanny': None,
#    'nthreads': 2,
#    'resources': {},
#    'services': {'dashboard': 43395},
#    'type': 'Worker'},
#   'inproc://172.28.0.2/61/57': {'host': '172.28.0.2',
#    'id': 2,
#    'local_directory': '/content/dask-worker-space/worker-vgi2gonc',
#    'memory_limit': 2000000000,
#    'name': 2,
# ...

# %%
cluster.status
# Out:
# <Status.running: 'running'>
